# %% [markdown]
# # Setup check
#
# Run this **before day 1**.
#
# 1. Top right, pick the kernel **Physalia spatial omics**.
# 2. Run All.
# 3. Last cell should print `SETUP OK`.
#
# If it does not, copy the whole status block into the course Slack.

# %%
# %cd ..

# %%
# !python scripts/healthcheck.py

# %% [markdown]
# If you saw `SETUP OK`, you are done — see you on day 1.
